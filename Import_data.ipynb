# %% [markdown]
# ## Overview
#
# 1. Understand the shape of the data (histograms, box plots, etc.)
#
# 2. Data Cleaning.
#
# 3. Data Exploration.
#
# 4. Feature Engineering.
#
# 5. Data Preprocessing for the Model.
#
# 6. Basic Model Building.
#
# 7. Model Tuning.
#
# 8. Ensemble model building.
#
# 9. Results.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.options.display.max_rows = 40
pd.options.display.max_rows = 30

# %%
financials = pd.read_csv('C:/Users/crump/Documents/University/755 Data Analytics/jpx_tokyo_se_prediction/train_files/financials.csv')

financials.info()
# Out:
# C:\Users\crump\AppData\Local\Temp\ipykernel_19068\417506630.py:1: DtypeWarning: Columns (14,15,16,17,18,19,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   financials = pd.read_csv('C:/Users/crump/Documents/University/755 Data Analytics/jpx_tokyo_se_prediction/train_files/financials.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92956 entries, 0 to 92955
# Data columns (total 45 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   DisclosureNumber                                                              92954 non-null  float64
#  1   DateCode                                                                      92954 non-null  object
#  2   Date                                                                          92956 non-null  object
# ...

# %%
options = pd.read_csv('C:/Users/crump/Documents/University/755 Data Analytics/jpx_tokyo_se_prediction/train_files/options.csv')

options.info()
# Out:
# C:\Users\crump\AppData\Local\Temp\ipykernel_19068\855227909.py:1: DtypeWarning: Columns (7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   options = pd.read_csv('C:/Users/crump/Documents/University/755 Data Analytics/jpx_tokyo_se_prediction/train_files/options.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3567694 entries, 0 to 3567693
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   DateCode             object
#  1   Date                 object
#  2   OptionsCode          int64
#  3   WholeDayOpen         float64
#  4   WholeDayHigh         float64
#  5   WholeDayLow          float64
#  6   WholeDayClose        float64
#  7   NightSessionOpen     object
#  8   NightSessionHigh     object
#  9   NightSessionLow      object
#  10  NightSessionClose    object
#  11  DaySessionOpen       float64
#  12  DaySessionHigh       float64
#  13  DaySessionLow        float64
# ...

# %%
secondary_stock_prices = pd.read_csv('C:/Users/crump/Documents/University/755 Data Analytics/jpx_tokyo_se_prediction/train_files/secondary_stock_prices.csv')

secondary_stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2384575 entries, 0 to 2384574
# Data columns (total 12 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   RowId             object
#  1   Date              object
#  2   SecuritiesCode    int64
#  3   Open              float64
#  4   High              float64
#  5   Low               float64
#  6   Close             float64
#  7   Volume            int64
#  8   AdjustmentFactor  float64
#  9   ExpectedDividend  float64
#  10  SupervisionFlag   bool
#  11  Target            float64
# dtypes: bool(1), float64(7), int64(2), object(2)
# memory usage: 202.4+ MB

# %%
stock_prices = pd.read_csv('C:/Users/crump/Documents/University/755 Data Analytics/jpx_tokyo_se_prediction/train_files/stock_prices.csv')

stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2332531 entries, 0 to 2332530
# Data columns (total 12 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   RowId             object
#  1   Date              object
#  2   SecuritiesCode    int64
#  3   Open              float64
#  4   High              float64
#  5   Low               float64
#  6   Close             float64
#  7   Volume            int64
#  8   AdjustmentFactor  float64
#  9   ExpectedDividend  float64
#  10  SupervisionFlag   bool
#  11  Target            float64
# dtypes: bool(1), float64(7), int64(2), object(2)
# memory usage: 198.0+ MB

# %%
trades = pd.read_csv('C:/Users/crump/Documents/University/755 Data Analytics/jpx_tokyo_se_prediction/train_files/trades.csv')

trades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1712 entries, 0 to 1711
# Data columns (total 56 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Date                                 1712 non-null   object
#  1   StartDate                            765 non-null    object
#  2   EndDate                              765 non-null    object
#  3   Section                              765 non-null    object
#  4   TotalSales                           765 non-null    float64
#  5   TotalPurchases                       765 non-null    float64
#  6   TotalTotal                           765 non-null    float64
#  7   TotalBalance                         765 non-null    float64
#  8   ProprietarySales                     765 non-null    float64
#  9   ProprietaryPurchases                 765 non-null    float64
#  10  ProprietaryTotal                     765 non-null    float64
# ...
